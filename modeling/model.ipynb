# %% [markdown]
# Imports:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

# %%
df = pd.read_csv('../assets/train.csv')
del df['result']
df.iloc[:100]
# Out:
#     sportsObjectsAmountPer100k  sportsAmountPer100k  areasSquarePer100k  \
# 0                        318.0                187.0        1.201111e+06
# 1                         84.0                  0.0        1.699444e+05
# 2                        400.0                238.0        4.766987e+05
# 3                        236.0                 44.0        4.707727e+04
# 4                        448.0                273.0        5.150813e+05
# ..                         ...                  ...                 ...
# 95                       171.0                 17.0        1.068602e+05
# 96                       403.0                344.0        4.644156e+05
# 97                       239.0                 24.0        9.496842e+04
# 98                       356.0                174.0        6.582989e+05
# 99                        64.0                 19.0        1.020557e+04
#
#     subwayDistance  pollutedPointsPercentage
# 0       835.506329                  0.003066
# ...
